# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import *
import scipy.stats

# %%
# Q1. Problem Statement: Measures of Dispersion
# Load the “HRdataset_v14.csv” dataset into a DataFrame and group the data
# based on the “Department” column. From the grouped DataFrame and perform
# the following tasks:
# 1. Calculate the Mean and Median, of the “Salary” column.
# 2. Find out which Department has the highest number of employees
# 3. Calculate the standard deviation and variance of the “Salary” column
# 4. Find the interquartile range of the "Salary" column
# 5. Find skewness and kurtosis of the original dataset
# 6. Find the z-score of the "Salary" column
# 7. Find the 30th percentile of the "Salary" column
# 8. Find the Quartiles of the "GenderID" column (You can set quartile values of
# your choice)

data = pd.read_csv("HRDataset_v14.csv")
data["Department"].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
data
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
data.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
# data["Salary"].mean()

salary_dep_mean= data.groupby("Department").agg( Salary_mean_as_per_dep = ("Salary", "mean"))
salary_dep_mean
# Out:
#                       Salary_mean_as_per_dep
# Department
# Admin Offices                   71791.888889
# Executive Office               250000.000000
# IT/IS                           97064.640000
# Production                      59953.545455
# Sales                           69061.258065
# Software Engineering            94989.454545

# %%
salary_dep_median = data.groupby("Department").agg( Salary_median_as_per_dep = ("Salary", "median"))
salary_dep_median
# Out:
#                       Salary_median_as_per_dep
# Department
# Admin Offices                          63003.0
# Executive Office                      250000.0
# IT/IS                                  92328.5
# Production                             59472.0
# Sales                                  65310.0
# Software Engineering                   95660.0

# %%
salary_dep = data.groupby("Department").agg( Salary_median_as_per_dep = ("Salary", "median"),Salary_mean_as_per_dep = ("Salary", "mean"))
salary_dep
# Out:
#                       Salary_median_as_per_dep  Salary_mean_as_per_dep
# Department
# Admin Offices                          63003.0            71791.888889
# Executive Office                      250000.0           250000.000000
# IT/IS                                  92328.5            97064.640000
# Production                             59472.0            59953.545455
# Sales                                  65310.0            69061.258065
# Software Engineering                   95660.0            94989.454545

# %%
dept_emp = data["Department"].value_counts().reset_index()
dept_emp_max = dept_emp["count"].max()
dept_emp_max_name = dept_emp[dept_emp["count"]==dept_emp_max]
dept_emp_max_name
# Out:
#           Department  count
# 0  Production           209

# %%
# 3. Calculate the standard deviation and variance of the “Salary” column

# salary_dep = data.groupby("Department").agg( Salary_dept_sd = pd.NamedAgg(column = "Salary", aggfunc=np.std))
# salary_dep

# import pandas as pd
# import numpy as np

# # Assuming you have a DataFrame 'data' with a "Department" and "Salary" column

# # Calculate the standard deviation and variance of the "Salary" column for each department
# salary_dep = data.groupby("Department").agg(
#     Salary_dept_sd = pd.NamedAgg(column="Salary", aggfunc=np.std),   # Standard Deviation
#     Salary_dept_var = pd.NamedAgg(column="Salary", aggfunc=np.var)   # Variance
# )

# print(salary_dep)


salary_dep = data.groupby("Department").agg( Salary_std_as_per_dep = ("Salary", "std"),Salary_var_as_per_dep = ("Salary", "var"))
salary_dep
# Out:
#                       Salary_std_as_per_dep  Salary_var_as_per_dep
# Department
# Admin Offices                  21706.397164           4.711677e+08
# Executive Office                        NaN                    NaN
# IT/IS                          33209.612190           1.102878e+09
# Production                     11422.656822           1.304771e+08
# Sales                          21271.393236           4.524722e+08
# Software Engineering            9566.505698           9.151803e+07

# %%
np.var(salary_dep[['Salary_std_as_per_dep','Salary_var_as_per_dep']], axis=0)
# Out:
# Salary_std_as_per_dep    7.197127e+07
# Salary_var_as_per_dep    1.314616e+17
# dtype: float64

# %%
salary_dep_mean= data.groupby("Department").agg( Salary_mean_as_per_dep = ("Salary", "mean"))
salary_dep_mean
np.var(salary_dep_mean['Salary_mean_as_per_dep'], axis=0)
# Out:
# 4264028200.173203

# %%
iqr(data[['Salary']], axis=0)
# Out:
# array([16534.5])

# %%
skew(data[["Salary"]], axis=0)
# Out:
# array([3.29021319])

# %%
numeric_data = data.select_dtypes(include=[np.number])

# Calculate kurtosis for the numeric columns
kurtosis_values = kurtosis(numeric_data, axis=0, nan_policy='omit')

print(kurtosis_values)
# Out:
# [-1.20002481 -1.82883388  2.00141533 -1.92925084 -1.4840155   2.18632909
#   3.96556573  5.82697481 15.18560705 -1.50719993  0.78011368 15.90911556
#   1.56226615  1.1266903  -0.76962535  0.61191877  8.66996019 -1.30035495]

# %%
zscore(data[["Salary"]], axis=0)
# Out:
#        Salary
# 0   -0.259382
# 1    1.410101
# 2   -0.161875
# 3   -0.160442
# 4   -0.724461
# ..        ...
# 306 -0.124529
# 307 -0.816514
# 308  6.029159
# 309  0.807102
# 310 -0.954552
#
# [311 rows x 1 columns]

# %%
np.percentile(data["Salary"],30,axis=0)
# Out:
# 57748.0

# %%
quartiles = data['GenderID'].quantile([0.25, 0.50, 0.75,1.00])

print("Quartiles of the 'GenderID' column:")
print(quartiles)
# Out:
# Quartiles of the 'GenderID' column:
# 0.25    0.0
# 0.50    0.0
# 0.75    1.0
# 1.00    1.0
# Name: GenderID, dtype: float64
